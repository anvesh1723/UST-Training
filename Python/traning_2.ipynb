# %%
def run():
    print("He his running")
print(run())
# Out:
# He his running
# None

# %%
def get_sum(lst):
    """ return all the sum of list """
    a_ll=0
    for num in lst:
        a_ll+=num
        print(all)
    return a_ll

lst=get_sum([1,2,3,4])

print(lst)
#print(a_ll)  we cannot access local variable in global
print(get_sum.__doc__)
# Out:
# <built-in function all>
# <built-in function all>
# <built-in function all>
# <built-in function all>
# 10
#  return all the sum of list

# %%
import math
def hcf(n1,n2):
    v=math.gcd(n1,n2)
    return v
print(hcf(2,3))
# Out:
# 1

# %%
l=-10
v=abs(l)
print(v)

l1=[1,2,"None"]
# Out:
# 10

# %%
l=[11,12,13,14]
for index, num in enumerate(l,start=1):
    print("index {0} has value {1}".format(index,num))
# Out:
# index 1 has value 11
# index 2 has value 12
# index 3 has value 13
# index 4 has value 14

# %%
n=20
if n>0:
    print("positive")

# %%
l=[1,2,-3,4]
l1=list(filter(lambda a:a>0, l))
print(l1)
# Out:
# [1, 2, 4]

# %%
lst1=[1,2,3]
l=[1,2]
print(isinstance(lst1,list))
# Out:
# True

# %%
v=list(map(lambda x:x*2,[1,2,3]))
print(v)
# Out:
# [2, 4, 6]

# %%
from functools import reduce
v=reduce(lambda x,y:x*y,[2,3,4])
print(v)
# Out:
# 24

# %%
v=[1,2,0]
print(any(v))
# Out:
# True

# %%
#default parameter
def say(x,y=1,z=1):
    v=x+y+z
    return v
print(say(1))

#print(say(2,y=1,4))
# Out:
# 3

# %%
#kwargs argument

def info(**kwargs):
    if kwargs:
        print("{0},{1}".format(kwargs['contact'], kwargs['name']))
info(contact=7569438842,name="anvesh")
# Out:
# 7569438842,anvesh

# %%
def lst(*names):
    print(names)
    for lst2 in names:
        print("Name {0}".format(lst2))

lst('ani','mini',1)
# Out:
# ('ani', 'mini', 1)
# Name ani
# Name mini
# Name 1

# %%
class member:
    def __init__(self,name,age,height):
        self.name=name
        self.age=age
        self.height=height
    def info(self,name,age):
        self.name=name
        self.age=age
test=member("Anvesh",21,6.7)
#test1=member()
#test1.info("Anvesh",21)

print(test.name)
#print(test1.name)
# Out:
# Anvesh

# %%
class m:
    def __init__(self,name):
        self.name=name
    def hello(self):
        print("Hello my name is "+self.name)
v=m("Anvesh")
print(v.name)
print(v.hello())
v.hello()
# Out:
# Anvesh
# Hello my name is Anvesh
# None
# Hello my name is Anvesh

# %%
class hello:
    def __init__(anvesh,name):
        anvesh.name=name
    def func(v):
        print("My name is "+ v.name)
v=hello("Sai")
print(v.name)
# Out:
# Sai

# %%
class abc:
    print("Hello")
class b(abc):
    print("Welcome")
v=b()
print(v)
# Out:
# Hello
# Welcome
# ...

# %%
class sport:
    def __init__(self, model,color,cost):
        self.model=model
        self.color=color
        self.cost=cost
        
    def getcost(self):
        return self.__cost
    def setcost(self,cost):
        self.__cost=cost
    def setcolor(self):
        self.__color=color
    def getbrand(self):
        self.__brand=brand
class shoes(sport):
    def __init__(self,model,color,cost,brand):
        super().__init__(model,color,cost)
        self.brand=brand

sh1=shoes("shoes","red","999","abc")
print(sh1)

# %%
# there are 2 types of error compile time and runtime

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
import sys
lst=['b',0,2]

for i in lst:
    try:
        print("Value is:",i)
        k=1/int(i)
    except:
        print("oh",sys.exc_info(),"occured.")
        print("next entry.")
        print("********")
print("the reciprocal of ", i ,"is",k)
# Out:
# Value is: b
# oh (<class 'ValueError'>, ValueError("invalid literal for int() with base 10: 'b'"), <traceback object at 0x00000289D55F4AC0>) occured.
# next entry.
# ********
# Value is: 0
# oh (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x00000289D55F4B80>) occured.
# next entry.
# ********
# Value is: 2
# the reciprocal of  2 is 0.5

# %%
import sys
try:
    x="anvesh"
    v=x[7]
except:
    print(sys.exc_info())
# Out:
# (<class 'IndexError'>, IndexError('string index out of range'), <traceback object at 0x00000289D55F6780>)

# %%
import sys
try:
    x=100+"100"
except:
    print(sys.exc_info())
# Out:
# (<class 'TypeError'>, TypeError("unsupported operand type(s) for +: 'int' and 'str'"), <traceback object at 0x00000289D55F6F80>)

# %%
import sys
ls=['b',0,2]

for i in ls:
    try:
        print(i)
        k=1/int(i)
    except(ValueError):
        print("This is Value Error")
    except(ZeroDivisionError):
        print("ZeroDivisionError")
    except:
        print("other error")
print("The reciprocal of", i ,"is",k )
# Out:
# b
# This is Value Error
# 0
# ZeroDivisionError
# 2
# The reciprocal of 2 is 0.5

# %%
raise KeyboardInterrupt

raise MemoryError("this is a memory error ") # we can write friendly error
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 raise KeyboardInterrupt
#       3 raise MemoryError("this is a memory error ")
#
# KeyboardInterrupt:

# %%
v=10
try:
    n=10/0
    raise ZeroDivisionError("enter other value")
except  ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
x=int(input())
try:
    y=10/x
finally:
    print("Issue in input")
# Out:
#  1
# Issue in input

# %%
import logging

logging.basicConfig(level=logging.INFO)

logging.debug("this is a debug")
logging.info("App  Started")
logging.warning("This is a Warning")
logging.error("An error occured")
logging.critical("Critical Issue!")
# Out:
# INFO:root:App  Started
# WARNING:root:This is a Warning
# ERROR:root:An error occured
# CRITICAL:root:Critical Issue!

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s- %(message)s'
)

# %%
logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s- %(message)s'
)

# %%
import sys
input_1=int(input("Enter number input 1:"))
input_2=int(input("Enter number input 2"))
op=input("Enter operation  (ADD OR SUB OR DIV OR MUL)").upper()
operation=['ADD','SUB','DIV','Mul']

if op=='ADD':
    print("Your number  input 1 is {} and input 2 is {} and result is {}".format(input_1,input_2,input_1+input_2))
elif op=="SUB":
    print("Your number  input 1 is {} and input 2 is {} and result is {}".format(input_1,input_2,input_1-input_2))
elif op=="MUL":
    print("Your number  input 1 is {} and input 2 is {} and result is {}".format(input_1,input_2,input_1*input_2))
elif op=="DIV":
    try:
        print("Your number  input 1 is {} and input 2 is {} and result is {}".format(input_1,input_2,input_1%input_2))
    except:
        print(sys.exc_info())
    finally:
        print("please select valid inputs")
else:
    print("please select valid operation")
# Out:
# Enter number input 1: 12
# Enter number input 2 0
# Enter (ADD OR SUB OR DIV OR MUL) div
# (<class 'ZeroDivisionError'>, ZeroDivisionError('integer modulo by zero'), <traceback object at 0x000001D95502AE80>)
# please select valid inputs
