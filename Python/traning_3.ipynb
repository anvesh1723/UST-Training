# %%
l=open("/Users/Administrator/Desktop/ani.txt")
print(l)
l.close()
# Out:
# <_io.TextIOWrapper name='/Users/Administrator/Desktop/ani.txt' mode='r' encoding='cp1252'>

# %%
import os
os.getenv("Home")
# Out:
# None

# %%
import os
os.getenv("/Users/Administrator")
ls=open("ani.txt","w")
ls.write("Anvesh is From Adilabad\n")
ls.write("Welcome")
ls.close()

# %%
ls=open("ani.txt","r")
ls.read()
# Out:
# 'Anvesh is From Adilabad\nWelcome'

# %%
import os
os.getenv("/Users/Administrator")
ls=open("/Users/Administrator/desktop/abc.txt","w")
ls.write("Anvesh is From Adilabad\n")
ls.write("Welcome")
ls.tell()
ls.close()

# %%
ls=open("ani.txt","r")
ls.read()
# Out:
# 'Anvesh is From Adilabad\nWelcome'

# %%
ls=open("ani.txt","r")
ls.read(3)
# Out:
# 'Anv'

# %%
ls.tell()
# Out:
# 3

# %%
ls.seek(2) # move pointer to a position
# Out:
# 2

# %%
ls.tell()
# Out:
# 2

# %%
ls.seek(0)
for i in ls:
    print(i)
# Out:
# Anvesh is From Adilabad
#
# Welcome

# %%
ls=open("ani.txt","r")
ls.readline()
ls.readline()
ls.close()

# %%
import os
os.getenv("/Users/Administrator")
os.rename("anvesh.txt","ani.txt")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.chdir("/Users/Administrator/desktop")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\desktop'

# %%
os.listdir(os.getcwd())
# Out:
# ['abc.txt',
#  'ani.txt',
#  'desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDB Compass.lnk',
#  'Readme - Shortcut.lnk']

# %%
os.mkdir("gananath")

# %%
os.listdir(os.getcwd())
# Out:
# ['abc.txt',
#  'ani.txt',
#  'desktop.ini',
#  'gananath',
#  'Microsoft Edge.lnk',
#  'MongoDB Compass.lnk',
#  'Readme - Shortcut.lnk']

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 10, 48, 37, 521666)

# %%
# import math as rename

import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
#from.. import statement
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 10, 50, 54, 945429)

# %%
#import all names
from math import *
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
# be confident
