# %%
import os
os.getenv("/Users/Administrator")
os.mkdir("/Users/Administrator/desktop/ust")

# %%
ls=open("/Users/Administrator/desktop/ust/ab.txt","w")

# %%
ls=open("/Users/Administrator/desktop/ust/ab.txt","w")
ls.write("welcome to india")
ls.close()

# %%
ls=open("/Users/Administrator/desktop/ust/ab.txt","r")
ls.read()
ls.close()

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\desktop\\ust'

# %%
os.remove("ab.txt")

# %%
os.rmdir("C:/Users/Administrator/desktop/ust")

# %%
import shutil
shutil.rmtree("C:/Users/Administrator/desktop/ust")
