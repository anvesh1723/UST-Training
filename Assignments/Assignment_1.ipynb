# %%
# Assignment 1

# %%
# Write python program fro matrix transpose

# %%
m=[[1,2],
  [3,4],
  [5,6]]
t=[]
for i in range(len(m[0])):
    row=[]
    for j in range(len(m)):
        row.append(m[j][i])
    t.append(row)
print(t)
# Out:
# [[1, 3, 5], [2, 4, 6]]

# %%
# Write python program fro matrix transpose using function

# %%
import numpy as np
a=np.array([[1,2],[3,4]])
v=np.transpose(a)
print(v)
# Out:
# [[1 3]
#  [2 4]]

# %%
#how can you access temporary deleted data using pop

# %%
l=[1,2,3]
a=l.pop()
print(a)
# Out:
# 3

# %%
#how you share element without sharing address

# %%
a=[1,23]
b=a.copy()
print(id(a))
print(id(b))
# Out:
# 2492739996608
# 2492740050048
